# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from preprocessing.preprocess import preprocess_data, tokenize

# %%
limit = 1000
# preprocess some data
sentences = preprocess_data(data_type='train', limit=limit)

print(sentences)

# preprocess and tokenize data
tokenized_data = tokenize(sentences)
    
print(tokenized_data)
# Out:
# ['أو قطع الأول يده إلخ', 'قوله', 'قال الزركشي', 'كإلقاء مصحف بقذر وشد زنار', 'وسحر', 'ابن عرفة قوله بلفظ يقتضيه كإنكار غير حديث بالإسلام وجوب ما علم وجوبه من الدين ضرورة', 'ابن عرفة قول ابن شاس أو بفعل يتضمنه هو كلبس الزنار وإلقاء المصحف في صريح النجاسة والسجود للصنم ونحو ذلك', 'محمد قول مالك وأصحابه أن الساحر كافر بالله تعالى قال مالك هو كالزنديق إذا عمل السحر بنفسه قتل ولم يستتب', 'قوله لعدم ما تتعلق إلخ', 'قوله ما مر', 'قوله فيعطى واحدة منها إلخ', 'أي الوصية', 'أي قبيل قول المتن لغت ولو اقتصر على أوصيت له بشاة أو أعطوه شاة ولا غنم له عند الموت هل تبطل الوصية أو يشترى له شاة ويؤخذ من قوله الآتي كما لو لم يقل من مالي ولا من غنمي أنها لا تبطل وعبارة الكنز ولو لم يقل من مالي ولا من غنمي لم يتعين غنمه إن كانت انتهت ا ه سم', 'كما لو كانت موجودة عند الوصية والموت ولا يجوز أن يعطى واحدة من غير غنمه في الصورتين وإن تراضيا لأنه صلح على مجهول مغني ونهاية قال ع ش قوله واحدة منها أي كاملة ولا يجوز أن يعطى نصفين من شاتين لأنه لا يسمى شاة وقوله ولا يجوز أن يعطى واحدة من غير غنمه وينبغي أن يقال م
# ...

# %% [markdown]
# # 1- Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import os
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# TODO: Implement extraction of Bag of Words feature
vectorizer = CountVectorizer(token_pattern=r'\S+',min_df = 1,max_df=20)
sentences_vectors = vectorizer.fit_transform(sentences)
print(sentences_vectors)
# Out:
#   (0, 5031)	1
#   (0, 7917)	1
#   (2, 1241)	1
#   (3, 5098)	1
#   (3, 6078)	1
#   (3, 2684)	1
#   (3, 7220)	1
#   (3, 3816)	1
#   (4, 7195)	1
#   (5, 4271)	1
#   (5, 2732)	1
#   (5, 8142)	1
#   (5, 5100)	1
#   (5, 3393)	1
#   (5, 2256)	1
#   (5, 7060)	1
#   (5, 4324)	1
#   (5, 7062)	1
#   (5, 1162)	1
#   (5, 4120)	1
#   (6, 4271)	1
#   (6, 3970)	1
#   (6, 2670)	1
#   (6, 7811)	1
#   (6, 5268)	1
#   :	:
#   (2923, 1478)	2
#   (2923, 118)	2
#   (2923, 7948)	1
#   (2923, 2710)	1
#   (2923, 3785)	1
#   (2923, 2053)	1
#   (2923, 523)	1
#   (2923, 6471)	1
#   (2923, 6525)	1
#   (2923, 8114)	3
#   (2923, 1980)	1
#   (2923, 208)	1
#   (2923, 7596)	1
#   (2923, 4383)	1
#   (2923, 1338)	1
#   (2923, 4491)	1
#   (2923, 4641)	1
#   (2923, 6472)	1
#   (2923, 4954)	1
#   (2923, 3077)	1
#   (2923, 7004)	1
#   (2923, 2766)	1
#   (2923, 7641)	1
#   (2923, 7156)	1
#   (2923, 6503)	1

# %%
tsne = TSNE(n_components=2)
x_t = tsne.fit_transform(x)
x1, x2, x3 = x_t[y1==0], x_t[y1==1], x_t[y1==2]
plt.scatter(x1[:,0], x1[:,1], c='red', s=0.7)
plt.scatter(x2[:,0], x2[:,1], c='teal', s=0.7)
plt.scatter(x3[:,0], x3[:,1], c='blue', s=0.7)
plt.show()
